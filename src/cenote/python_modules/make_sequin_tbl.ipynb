# %%
import os
import sys
import pandas as pd
import math
import re
import numpy as np

# %%
gene_contig_file = "/Users/michaeltisza/mike_tisza/sandbox/test_SRS_0808d/ct2_tmp/contig_gene_annotation_summary.pruned.tsv"

tRNA_table = "/Users/michaeltisza/mike_tisza/sandbox/test_SRS_0808d/ct2_tmp/oriented_hallmark_contigs.pruned.tRNAscan.tsv"

# %%
gene_contig_df = pd.read_csv(gene_contig_file, sep = "\t")

tRNA_df = pd.read_csv(tRNA_table, index_col=False, sep = "\t", names = ['con_chunk', 'tRNA_num', 'gene_c1', 'gene_c2', 
                                                                      'evidence_description', 'tRNA_codon', 'other1', 'other2', 'tRNA_score'])

tRNA_df['at_pos'] = tRNA_df['con_chunk'].str.find("@")

tRNA_df['contig'] = tRNA_df.apply(
    lambda x: x["con_chunk"][0:x["at_pos"]], axis = 1)

tRNA_df['chunk_name'] = tRNA_df.apply(
    lambda x: x["con_chunk"][x["at_pos"]+1:-1], axis = 1)

tRNA_df['gene_start'] = np.where(tRNA_df['gene_c1'] < tRNA_df['gene_c2'], tRNA_df['gene_c1'], tRNA_df['gene_c2'])

tRNA_df['gene_stop'] = np.where(tRNA_df['gene_c1'] > tRNA_df['gene_c2'], tRNA_df['gene_c1'], tRNA_df['gene_c2'])

tRNA_df['gene_orient'] = np.where(tRNA_df['gene_c1'] < tRNA_df['gene_c2'], "+", "-")

tRNA_df['evidence_acession'] = "tRNAscan-SE score: " + tRNA_df['tRNA_score'].astype(str)

tRNA_df['Evidence_source'] = "tRNAscan-SE"

tRNA_df['gene_name'] = "tRNA-" + tRNA_df['evidence_description'].astype(str)

tRNA_df = tRNA_df[['contig', 'chunk_name', 'gene_start', 'gene_stop', 'gene_name', 
                   'gene_orient', 'evidence_description', 'evidence_acession', 'Evidence_source']]

tRNA_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/rt/99qysh710s912gh030fg631w0000gr/T/ipykernel_8509/277080727.py in ?()
#       4                                                                       'evidence_description', 'tRNA_codon', 'other1', 'other2', 'tRNA_score'])
#       5
#       6 tRNA_df['at_pos'] = tRNA_df['con_chunk'].str.find("@")
#       7
# ----> 8 tRNA_df['contig'] = tRNA_df.apply(
#       9     lambda x: x["con_chunk"][0:x["at_pos"]], axis = 1)
#      10
#      11 tRNA_df['chunk_name'] = tRNA_df.apply(
#
# ~/miniconda3/envs/ct2_dev/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, key, value)
#    3936             self._setitem_frame(key, value)
#    3937         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    3938             self._setitem_array(key, value)
#    3939         elif isinstance(value, DataFrame):
# -> 3940             self._set_item_frame_value(key, value)
#    3941         elif (
#    3942             is_list_like(value)
#    3943             and not self.columns.is_unique
#
# ~/miniconda3/envs/ct2_dev/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, key, value)
#    4090             self._set_item_mgr(key, arraylike)
#    4091             return
#    4092
#    4093         if len(value.columns) != 1:
# -> 4094             raise ValueError(
#    4095                 "Cannot set a DataFrame with multiple columns to the single "
#    4096                 f"column {key}"
#    4097             )
#
# ValueError: Cannot set a DataFrame with multiple columns to the single column contig

# %%
#test_df = gene_contig_df.merge(tRNA_df, how = "left", on = ['contig', 'chunk_name'])

test_df = pd.concat([gene_contig_df, tRNA_df], ignore_index=True)

# %%
test_df['chunk_name'] = test_df['chunk_name'].fillna("nochunk")

# %%
chunk_grouped_df = test_df.groupby(['contig', 'chunk_name'], dropna = False)


test_chunk = chunk_grouped_df.get_group(('test_SRS_0803e43597', 'Chunk_0'))

test_chunk.query("Evidence_source == 'tRNAscan-SE'")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 4
#       1 chunk_grouped_df = test_df.groupby(['contig', 'chunk_name'], dropna = False)
# ----> 4 test_chunk = chunk_grouped_df.get_group(('test_SRS_0803e43597', 'Chunk_0'))
#       6 test_chunk.query("Evidence_source == 'tRNAscan-SE'")
#
# File ~/miniconda3/envs/ct2_dev/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:800, in BaseGroupBy.get_group(self, name, obj)
#     798 inds = self._get_index(name)
#     799 if not len(inds):
# --> 800     raise KeyError(name)
#     802 return obj._take_with_is_copy(inds, axis=self.axis)
#
# KeyError: ('test_SRS_0803e43597', 'Chunk_0')

# %%
#list(chunk_grouped_df.groups)

# %%
#test_chunk.first

if not test_chunk['chunk_name'].agg(pd.Series.mode)[0] == "no_chunk":  
    print(">Feature " + test_chunk['contig'].agg(pd.Series.mode)[0] + "@" + \
          test_chunk['chunk_name'].agg(pd.Series.mode)[0] + " Table1")
else:
    print(">Feature " + test_chunk['contig'].agg(pd.Series.mode)[0] + " Table1")    

for index, row in test_chunk.iterrows():
    trna_number = 1

    if row['Evidence_source'] == "hallmark_hmm" or row['Evidence_source'] == "common_virus_hmm": #my hmms
        tagstr = ("protein_id" + "\tlcl|" + row['gene_name'])
        productstr = re.sub("-", " ", row['evidence_description'])
        inferencestr = ("inference\tprotein motif " + str(row['evidence_acession']))
    
    elif row['Evidence_source'] == "mmseqs_cdd":  #mmseqs_cdd
        
        tagstr = ("protein_id" + "\tlcl|" + row['gene_name'])
        productstr = re.sub("\..*", "", row['evidence_description'])
        inferencestr = ("inference\tprotein motif CDD:" + str(row['evidence_acession']))

    elif row['Evidence_source'] == "tRNAscan-SE": ## tRNAs
        tagstr = ("gene\ttRNA" + str(trna_number))
        productstr = row['gene_name']
        inferencestr = ("inference\t" + row['evidence_acession'])
        trna_number =+ 1

    elif pd.isnull(row['Evidence_source']): #hypos
        tagstr = ("protein_id" + "\tlcl|" + row['gene_name'])
        productstr = row['evidence_description']
        inferencestr = ("note\tno search hits")
    else:
        raise Exception("this shouldn't happen")
        tagstr = "help"
        productstr = "help"
        inferencestr = "help"        
    
    print(str(row['gene_start']) + "\t" + str(row['gene_stop']))
    print("\t\t\t" + tagstr )
    print("\t\t\tproduct" + "\t" + productstr )
    print("\t\t\t" + inferencestr )
# Out:
# >Feature test_SRS_0803e43597@Chunk_0 Table1
# 385	565
# 			protein_id	lcl|test_SRS_0803e43597_3
# 			product	hypothetical protein
# 			note	no search hits
# 642	750
# 			protein_id	lcl|test_SRS_0803e43597_4
# 			product	hypothetical protein
# 			note	no search hits
# 721	841
# 			protein_id	lcl|test_SRS_0803e43597_5
# 			product	hypothetical protein
# 			note	no search hits
# 973	1990
# 			protein_id	lcl|test_SRS_0803e43597_6
# 			product	hypothetical protein
# 			note	no search hits
# 2054	2375
# 			protein_id	lcl|test_SRS_0803e43597_7
# 			product	hypothetical protein
# 			note	no search hits
# 2436	2592
# 			protein_id	lcl|test_SRS_0803e43597_8
# 			product	hypothetical protein
# 			note	no search hits
# 2605	2818
# 			protein_id	lcl|test_SRS_0803e43597_9
# 			product	hypothetical protein
# 			note	no search hits
# 2817	3012
# 			protein_id	lcl|test_SRS_0803e43597_10
# 			product	hypothetical protein
# 			note	no search hits
# 3004	3346
# 			protein_id	lcl|test_SRS_0803e43597_11
# 			product	hypothetical protein
# 			note	no search hits
# 3338	3683
# 			protein_id	lcl|test_SRS_0803e43597_12
# 			product	hypothetical protein
# 			note	no search hits
# 3675	4032
# 			protein_id	lcl|test_SRS_0803e43597_13
# 			product	hypothetical protein
# 			note	no search hits
# 4031	4376
# 			protein_id	lcl|test_SRS_0803e43597_14
# 			product	hypothetical protein
# 			note	no search hits
# 4402	5941
# 			protein_id	lcl|test_SRS_0803e43597_15
# 			product	hypothetical protein
# 			note	no search hits
# 5953	7087
# 			protein_id	lcl|test_SRS_0803e43597_16
# 			product	hypothetical protein
# 			note	no search hits
# 7155	7314
# 			protein_id	lcl|test_SRS_0803e43597_17
# 			product	hypothetical protein
# 			note	no search hits
# 7353	7446
# 			protein_id	lcl|test_SRS_0803e43597_18
# 			product	hypothetical protein
# 			note	no search hits
# 7442	7574
# 			protein_id	lcl|test_SRS_0803e43597_19
# 			product	hypothetical protein
# 			note	no search hits
# 7556	8441
# 			protein_id	lcl|test_SRS_0803e43597_20
# 			product	hypothetical protein
# 			note	no search hits
# 8406	10194
# 			protein_id	lcl|test_SRS_0803e43597_21
# 			product	replicative DNA helicase
# 			inference	protein motif PDB:1NLF_A
# 10078	10645
# 			protein_id	lcl|test_SRS_0803e43597_22
# 			product	hypothetical protein
# 			note	no search hits
# 10646	10859
# 			protein_id	lcl|test_SRS_0803e43597_23
# 			product	hypothetical protein
# 			note	no search hits
# 10852	12775
# 			protein_id	lcl|test_SRS_0803e43597_24
# 			product	DNA POLYMERASE
# 			inference	protein motif PDB:2KFZ_A
# 12774	13245
# 			protein_id	lcl|test_SRS_0803e43597_25
# 			product	hypothetical protein
# 			note	no search hits
# 13231	13417
# 			protein_id	lcl|test_SRS_0803e43597_26
# 			product	hypothetical protein
# 			note	no search hits
# 13379	13880
# 			protein_id	lcl|test_SRS_0803e43597_27
# 			product	hypothetical protein
# 			note	no search hits
# 13967	14642
# 			protein_id	lcl|test_SRS_0803e43597_28
# 			product	hypothetical protein
# 			note	no search hits
# 14589	15030
# 			protein_id	lcl|test_SRS_0803e43597_29
# 			product	hypothetical protein
# 			note	no search hits
# 15010	15163
# 			protein_id	lcl|test_SRS_0803e43597_30
# 			product	hypothetical protein
# 			note	no search hits
# 15159	15600
# 			protein_id	lcl|test_SRS_0803e43597_31
# 			product	hypothetical protein
# 			note	no search hits
# 15596	15869
# 			protein_id	lcl|test_SRS_0803e43597_32
# 			product	hypothetical protein
# 			note	no search hits
# 15865	16663
# 			protein_id	lcl|test_SRS_0803e43597_33
# 			product	PD (D E)XK nuclease superfamily
# 			inference	protein motif PFAM:PF12705.6
# 16768	17053
# 			protein_id	lcl|test_SRS_0803e43597_34
# 			product	hypothetical protein
# 			note	no search hits
# 17099	17279
# 			protein_id	lcl|test_SRS_0803e43597_35
# 			product	hypothetical protein
# 			note	no search hits
# 17235	17754
# 			protein_id	lcl|test_SRS_0803e43597_36
# 			product	Dihydrofolate reductase (DHFR)
# 			inference	protein motif CDD:cd00209
# 17753	18056
# 			protein_id	lcl|test_SRS_0803e43597_37
# 			product	hypothetical protein
# 			note	no search hits
# 18048	18141
# 			protein_id	lcl|test_SRS_0803e43597_38
# 			product	hypothetical protein
# 			note	no search hits
# 18140	18527
# 			protein_id	lcl|test_SRS_0803e43597_39
# 			product	nucelotide kinase
# 			inference	protein motif PFAM:PF11753.7
# 18519	19038
# 			protein_id	lcl|test_SRS_0803e43597_40
# 			product	dUTPase [Nucleotide transport and metabolism, Defense mechanisms]
# 			inference	protein motif CDD:COG0756
# 19044	19788
# 			protein_id	lcl|test_SRS_0803e43597_41
# 			product	AAA domain protein
# 			inference	protein motif PFAM:PF13479.5
# 19787	20204
# 			protein_id	lcl|test_SRS_0803e43597_42
# 			product	hypothetical protein
# 			note	no search hits
# 20582	21485
# 			protein_id	lcl|test_SRS_0803e43597_43
# 			product	hypothetical protein
# 			note	no search hits
# 21444	21672
# 			protein_id	lcl|test_SRS_0803e43597_44
# 			product	hypothetical protein
# 			note	no search hits
# 21643	21916
# 			protein_id	lcl|test_SRS_0803e43597_45
# 			product	hypothetical protein
# 			note	no search hits
# 21912	22200
# 			protein_id	lcl|test_SRS_0803e43597_46
# 			product	hypothetical protein
# 			note	no search hits
# 22209	22521
# 			protein_id	lcl|test_SRS_0803e43597_47
# 			product	hypothetical protein
# 			note	no search hits
# 22530	22839
# 			protein_id	lcl|test_SRS_0803e43597_48
# 			product	hypothetical protein
# 			note	no search hits
# 22835	23129
# 			protein_id	lcl|test_SRS_0803e43597_49
# 			product	hypothetical protein
# 			note	no search hits
# 23125	23251
# 			protein_id	lcl|test_SRS_0803e43597_50
# 			product	hypothetical protein
# 			note	no search hits
# 23244	23430
# 			protein_id	lcl|test_SRS_0803e43597_51
# 			product	hypothetical protein
# 			note	no search hits
# 23439	23730
# 			protein_id	lcl|test_SRS_0803e43597_52
# 			product	hypothetical protein
# 			note	no search hits
# 23757	24615
# 			protein_id	lcl|test_SRS_0803e43597_53
# 			product	hypothetical protein
# 			note	no search hits
# 24614	25994
# 			protein_id	lcl|test_SRS_0803e43597_54
# 			product	hypothetical protein
# 			note	no search hits
# 25993	27121
# 			protein_id	lcl|test_SRS_0803e43597_55
# 			product	hypothetical protein
# 			note	no search hits
# 27120	28752
# 			protein_id	lcl|test_SRS_0803e43597_56
# 			product	hypothetical protein
# 			note	no search hits
# 28751	29318
# 			protein_id	lcl|test_SRS_0803e43597_57
# 			product	hypothetical protein
# 			note	no search hits
# 29317	30592
# 			protein_id	lcl|test_SRS_0803e43597_58
# 			product	hypothetical protein
# 			note	no search hits
# 30600	30963
# 			protein_id	lcl|test_SRS_0803e43597_59
# 			product	hypothetical protein
# 			note	no search hits
# 30962	31166
# 			protein_id	lcl|test_SRS_0803e43597_60
# 			product	phage holin Dp 1
# 			inference	protein motif PFAM:PF16938.4
# 31176	31710
# 			protein_id	lcl|test_SRS_0803e43597_61
# 			product	hypothetical protein
# 			note	no search hits
# 31719	32175
# 			protein_id	lcl|test_SRS_0803e43597_62
# 			product	hypothetical protein
# 			note	no search hits
# 32177	32744
# 			protein_id	lcl|test_SRS_0803e43597_63
# 			product	hypothetical protein
# 			note	no search hits
# 32786	36443
# 			protein_id	lcl|test_SRS_0803e43597_64
# 			product	hypothetical protein
# 			note	no search hits
# 36439	37462
# 			protein_id	lcl|test_SRS_0803e43597_65
# 			product	GH25_LysA like endolysin
# 			inference	protein motif CDD:cd06417
# 37448	37793
# 			protein_id	lcl|test_SRS_0803e43597_66
# 			product	hypothetical protein
# 			note	no search hits
# 37785	38109
# 			protein_id	lcl|test_SRS_0803e43597_67
# 			product	hypothetical protein
# 			note	no search hits
# 38111	39173
# 			protein_id	lcl|test_SRS_0803e43597_68
# 			product	CHAP domain
# 			inference	protein motif CDD:pfam05257
# 39184	39469
# 			protein_id	lcl|test_SRS_0803e43597_69
# 			product	hypothetical protein
# 			note	no search hits
# 39455	39662
# 			protein_id	lcl|test_SRS_0803e43597_70
# 			product	hypothetical protein
# 			note	no search hits
# 39670	40924
# 			protein_id	lcl|test_SRS_0803e43597_71
# 			product	structural protein
# 			inference	protein motif UniProtKB:C3U2R6_9CAUD
# 40932	42210
# 			protein_id	lcl|test_SRS_0803e43597_72
# 			product	hypothetical protein
# 			note	no search hits
# 42206	43313
# 			protein_id	lcl|test_SRS_0803e43597_73
# 			product	hypothetical protein
# 			note	no search hits
# 43312	47731
# 			protein_id	lcl|test_SRS_0803e43597_74
# 			product	tail tape measure
# 			inference	protein motif Uniprot:T2PM72_GARVA
# 47746	49102
# 			protein_id	lcl|test_SRS_0803e43597_75
# 			product	hypothetical protein
# 			note	no search hits
# 49102	49327
# 			protein_id	lcl|test_SRS_0803e43597_76
# 			product	hypothetical protein
# 			note	no search hits
# 49337	49910
# 			protein_id	lcl|test_SRS_0803e43597_77
# 			product	hypothetical protein
# 			note	no search hits
# 49906	50314
# 			protein_id	lcl|test_SRS_0803e43597_78
# 			product	hypothetical protein
# 			note	no search hits
# 50375	50876
# 			protein_id	lcl|test_SRS_0803e43597_79
# 			product	hypothetical protein
# 			note	no search hits
# 50886	51189
# 			protein_id	lcl|test_SRS_0803e43597_80
# 			product	hypothetical protein
# 			note	no search hits
# 51182	51968
# 			protein_id	lcl|test_SRS_0803e43597_81
# 			product	hypothetical protein
# 			note	no search hits
# 51979	53167
# 			protein_id	lcl|test_SRS_0803e43597_82
# 			product	structural protein
# 			inference	protein motif UniProtKB:C3U2Q3_9CAUD
# 53168	54245
# 			protein_id	lcl|test_SRS_0803e43597_83
# 			product	hypothetical protein
# 			note	no search hits
# 54244	54571
# 			protein_id	lcl|test_SRS_0803e43597_84
# 			product	hypothetical protein
# 			note	no search hits
# 54563	54698
# 			protein_id	lcl|test_SRS_0803e43597_85
# 			product	hypothetical protein
# 			note	no search hits
# 54697	54982
# 			protein_id	lcl|test_SRS_0803e43597_86
# 			product	hypothetical protein
# 			note	no search hits
# 55059	55644
# 			protein_id	lcl|test_SRS_0803e43597_87
# 			product	hypothetical protein
# 			note	no search hits
# 55636	55966
# 			protein_id	lcl|test_SRS_0803e43597_88
# 			product	hypothetical protein
# 			note	no search hits
# 56048	56594
# 			protein_id	lcl|test_SRS_0803e43597_89
# 			product	hypothetical protein
# 			note	no search hits
# 56601	57945
# 			protein_id	lcl|test_SRS_0803e43597_90
# 			product	HK97 Family Phage Portal Protein
# 			inference	protein motif PDB:3KDR_A
# 57944	59585
# 			protein_id	lcl|test_SRS_0803e43597_91
# 			product	large terminase
# 			inference	protein motif PDB:4IEE_A
# 59538	60219
# 			protein_id	lcl|test_SRS_0803e43597_92
# 			product	hypothetical protein
# 			note	no search hits
# 60218	60578
# 			protein_id	lcl|test_SRS_0803e43597_93
# 			product	hypothetical protein
# 			note	no search hits
# 60937	61396
# 			protein_id	lcl|test_SRS_0803e43597_94
# 			product	hypothetical protein
# 			note	no search hits
# 61424	61637
# 			protein_id	lcl|test_SRS_0803e43597_95
# 			product	hypothetical protein
# 			note	no search hits
# 61610	61757
# 			protein_id	lcl|test_SRS_0803e43597_96
# 			product	hypothetical protein
# 			note	no search hits
# 61838	62786
# 			protein_id	lcl|test_SRS_0803e43597_97
# 			product	hypothetical protein
# 			note	no search hits
# 60733	60806
# 			gene	tRNA1
# 			product	tRNA-Cys
# 			inference	tRNAscan-SE score: 58.9
# 60604	60677
# 			gene	tRNA1
# 			product	tRNA-Arg
# 			inference	tRNAscan-SE score: 66.5

# %%
chunk_grouped_df = test_df.groupby(['contig', 'chunk_name'], dropna = False)

# %%
for name, seq_group in chunk_grouped_df:
    print(f">Feature {name[0]}@{name[1]} Table1")
# Out:
# >Feature test_ct2_0804a_103@nochunk Table1
# >Feature test_ct2_0804a_1048@nochunk Table1
# >Feature test_ct2_0804a_1085@nochunk Table1
# >Feature test_ct2_0804a_1339@nochunk Table1
# >Feature test_ct2_0804a_1392@nochunk Table1
# >Feature test_ct2_0804a_1552@nochunk Table1
# >Feature test_ct2_0804a_1584@nochunk Table1
# >Feature test_ct2_0804a_1658@nochunk Table1
# >Feature test_ct2_0804a_1675@nochunk Table1
# >Feature test_ct2_0804a_1690@nochunk Table1
# >Feature test_ct2_0804a_1706@nochunk Table1
# >Feature test_ct2_0804a_1724@nochunk Table1
# >Feature test_ct2_0804a_1807@nochunk Table1
# >Feature test_ct2_0804a_1853@nochunk Table1
# >Feature test_ct2_0804a_188@nochunk Table1
# >Feature test_ct2_0804a_194@nochunk Table1
# >Feature test_ct2_0804a_1951@nochunk Table1
# >Feature test_ct2_0804a_2008@nochunk Table1
# >Feature test_ct2_0804a_2046@nochunk Table1
# >Feature test_ct2_0804a_2084@nochunk Table1
# >Feature test_ct2_0804a_2112@nochunk Table1
# >Feature test_ct2_0804a_2224@nochunk Table1
# >Feature test_ct2_0804a_226@nochunk Table1
# >Feature test_ct2_0804a_2344@nochunk Table1
# >Feature test_ct2_0804a_2398@nochunk Table1
# >Feature test_ct2_0804a_2455@nochunk Table1
# >Feature test_ct2_0804a_2538@nochunk Table1
# >Feature test_ct2_0804a_2791@nochunk Table1
# >Feature test_ct2_0804a_3193@Chunk_0 Table1
# >Feature test_ct2_0804a_3340@Chunk_0 Table1
# >Feature test_ct2_0804a_3581@Chunk_0 Table1
# >Feature test_ct2_0804a_3598@nochunk Table1
# >Feature test_ct2_0804a_3616@nochunk Table1
# >Feature test_ct2_0804a_3657@Chunk_0 Table1
# >Feature test_ct2_0804a_3731@nochunk Table1
# >Feature test_ct2_0804a_3758@nochunk Table1
# >Feature test_ct2_0804a_3822@nochunk Table1
# >Feature test_ct2_0804a_3847@nochunk Table1
# >Feature test_ct2_0804a_3852@nochunk Table1
# >Feature test_ct2_0804a_3995@nochunk Table1
# >Feature test_ct2_0804a_4079@nochunk Table1
# >Feature test_ct2_0804a_4253@nochunk Table1
# >Feature test_ct2_0804a_4368@nochunk Table1
# >Feature test_ct2_0804a_4448@nochunk Table1
# >Feature test_ct2_0804a_461@nochunk Table1
# >Feature test_ct2_0804a_4645@nochunk Table1
# >Feature test_ct2_0804a_4675@nochunk Table1
# >Feature test_ct2_0804a_4689@nochunk Table1
# >Feature test_ct2_0804a_4703@nochunk Table1
# >Feature test_ct2_0804a_473@nochunk Table1
# >Feature test_ct2_0804a_4781@nochunk Table1
# >Feature test_ct2_0804a_4793@nochunk Table1
# >Feature test_ct2_0804a_4889@nochunk Table1
# >Feature test_ct2_0804a_4943@nochunk Table1
# >Feature test_ct2_0804a_4954@nochunk Table1
# >Feature test_ct2_0804a_504@nochunk Table1
# >Feature test_ct2_0804a_5065@nochunk Table1
# >Feature test_ct2_0804a_5368@nochunk Table1
# >Feature test_ct2_0804a_5461@nochunk Table1
# >Feature test_ct2_0804a_5462@nochunk Table1
# >Feature test_ct2_0804a_5769@nochunk Table1
# >Feature test_ct2_0804a_578@nochunk Table1
# >Feature test_ct2_0804a_5854@nochunk Table1
# >Feature test_ct2_0804a_5856@nochunk Table1
# >Feature test_ct2_0804a_5934@nochunk Table1
# >Feature test_ct2_0804a_6023@nochunk Table1
# >Feature test_ct2_0804a_6080@nochunk Table1
# >Feature test_ct2_0804a_6137@Chunk_0 Table1
# >Feature test_ct2_0804a_6148@nochunk Table1
# >Feature test_ct2_0804a_6150@nochunk Table1
# >Feature test_ct2_0804a_6168@nochunk Table1
# >Feature test_ct2_0804a_6182@nochunk Table1
# >Feature test_ct2_0804a_6269@nochunk Table1
# >Feature test_ct2_0804a_6290@nochunk Table1
# >Feature test_ct2_0804a_6327@nochunk Table1
# >Feature test_ct2_0804a_6354@nochunk Table1
# >Feature test_ct2_0804a_6438@nochunk Table1
# >Feature test_ct2_0804a_75@nochunk Table1
# >Feature test_ct2_0804a_790@nochunk Table1
# >Feature test_ct2_0804a_892@nochunk Table1
# >Feature test_ct2_0804a_905@nochunk Table1

# %%
gene_contig_df['chunk_name'] = gene_contig_df['chunk_name'].fillna("nochunk")

grouped_df = gene_contig_df.groupby(['contig', 'chunk_name'], dropna = False)

# %%
def tbl_first_second(gstart, gstop, gorient):
    if gorient == "+":
        return gstart, gstop, gorient
    else:
        return gstop, gstart, gorient

#### loop each virus 
for name, seq_group in grouped_df:

    for index, row in seq_group.iterrows():
        #print(tbl_first_second(row['gene_start'], row['gene_stop'], row['gene_orient']))
        first_c, second_c = tbl_first_second(row['gene_start'], row['gene_stop'], row['gene_orient'])[0,1]
        print(first_c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 12
#       8 for name, seq_group in grouped_df:
#      10     for index, row in seq_group.iterrows():
#      11         #print(tbl_first_second(row['gene_start'], row['gene_stop'], row['gene_orient']))
# ---> 12         first_c, second_c = tbl_first_second(row['gene_start'], row['gene_stop'], row['gene_orient'])[0,1]
#      13         print(first_c)
#
# TypeError: tuple indices must be integers or slices, not tuple
